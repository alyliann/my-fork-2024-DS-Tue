# %% [markdown]
# # Fall 2024 Data Science Track: Week 5 - Unsupervised Learning

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need: `matplotlib`, `networkx`, `numpy`, and `pandas`―and also `ast.literal_eval` to correctly deserialize two columns in the `rules.tsv.xz` file.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Don’t worry about this. This is needed to interpret the Python code that is embedded in the data set. You only need it literally in the very next code cell and nowhere else. 
from ast import literal_eval

# The rest is just the stuff from the lecture.
from matplotlib import pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd

# %% [markdown]
# # Instacart Association Rules

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the Instacart association rules data set, mined from the [Instacart Market Basket Analysis data set](https://www.kaggle.com/c/instacart-market-basket-analysis/data) on Kaggle. [The script](https://github.com/LiKenun/shopping-assistant/blob/main/api/preprocess_instacart_market_basket_analysis_data.py) that does it and the instructions to run it can be found in my [Shopping Assistant Project](https://github.com/LiKenun/shopping-assistant) repository.

# %% [markdown]
# ## Load the Data
#
# This code has already been pre-written, simply because there are a few quirks which require converters to ensure the correct deserialization of some columns.

# %%
rules_data_path = 'data/rules.tsv.xz'                       # You do not need to decompress this yourself. Pandas understands how to read compressed data.

df_rules = pd.read_csv(rules_data_path,
                       sep='\t',
                       quoting=3,                           # This disables interpretation of quotes by Pandas itself, because both single and double quotes will be resolved by literal_eval.
                       converters={
                           'consequent_item': literal_eval,
                           'antecedent_items': literal_eval # This reads something like ["Grandma's 8\" Chip Cookies", '6" Apple Pie'] into a list, so you will get a column where each individual cell is a list.
                       },
                       low_memory=True)                     # For Chris
# Out:
# <unknown>:1: SyntaxWarning: invalid escape sequence '\G'

# %% [markdown]
# But just *how* many rules were just loaded‽

# %%
# Show the list of column names and the number of rules.

print(df_rules.columns)  # column names
len(df_rules)
# Out:
# Index(['consequent_item', 'transaction_count', 'item_set_count',
#        'antecedent_count', 'consequent_count', 'antecedent_items'],
#       dtype='object')
# 1048575

# %% [markdown]
# ## Metrics
#
# Compute the support, confidence, and lift of each rule.
#
# * The rule’s *support* tells you how frequently the set of items appears in the dataset. It’s important to prune infrequent sets from further consideration.
#     * The simple definition: $$P(A \cap B)$$
#     * `= item_set_count / transaction_count`
# * The rule’s *confidence* tells you how often a the rule is true. Divide the support for the set of items by the support for just the antecedents. Rules which are not true very often are also pruned.
#     * The simple definition: $$\frac{P(A \cap B)}{P(A)}$$
#     * `= item_set_count / transaction_count / (antecedent_count / transaction_count)`
#     * `= item_set_count / antecedent_count`
# * The rule’s *lift* tells you how much more likely the consequent is, given the antecedents, compared to its baseline probability. Divide the support for the set of items by both the support of the antecedents and consequent. Equivalently, divide the confidence by the support of the consequent.
#     * The simple definition: $$\frac{P(A \cap B)}{P(A) \cdot P(B)}$$
#     * `= item_set_count / transaction_count / (antecedent_count / transaction_count * (consequent_count / transaction_count))`
#     * `= item_set_count / antecedent_count / (consequent_count / transaction_count)`
#     * `= item_set_count * transaction_count / (antecedent_count * consequent_count)`

# %%
# Add new columns support, confidence, and lift to df_rules. And show the first 50 rules.

# How frequently the set of items appears in the dataset:
df_rules['support'] = df_rules['item_set_count'] / \
    df_rules['transaction_count']

# How often a rule is true/how confident we are this association exists:
df_rules['confidence'] = df_rules['item_set_count'] / \
    df_rules['antecedent_count']

# How much more likely they are to buy the associated item:
df_rules['lift'] = (df_rules['item_set_count'] * df_rules['transaction_count'] / (df_rules['antecedent_count'] * df_rules['consequent_count'])).round()
# df_rules['lift'] = df_rules['confidence'] / df_rules['support']

df_rules.head(n=50)
# Out:
#                                       consequent_item  transaction_count  \
# 0   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 1   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 2    Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 3                           Total 0% Raspberry Yogurt            3346083
# 4                                 Pineapple Yogurt 2%            3346083
# 5                          Fat Free Strawberry Yogurt            3346083
# 6                           Fat Free Blueberry Yogurt            3346083
# 7   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 8   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 9   Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 10  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 11                          Total 0% Raspberry Yogurt            3346083
# 12                                Pineapple Yogurt 2%            3346083
# 13                         Fat Free Strawberry Yogurt            3346083
# 14                                  Blackberry Yogurt            3346083
# 15  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 16  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 17   Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 18                          Total 0% Raspberry Yogurt            3346083
# 19                                Pineapple Yogurt 2%            3346083
# 20                         Fat Free Strawberry Yogurt            3346083
# 21                          Fat Free Blueberry Yogurt            3346083
# 22  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 23  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 24  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 25  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 26                          Total 0% Raspberry Yogurt            3346083
# 27                                Pineapple Yogurt 2%            3346083
# 28                         Fat Free Strawberry Yogurt            3346083
# 29                                  Blackberry Yogurt            3346083
# 30  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 31  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 32   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 33  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 34  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 35  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 36                          Total 0% Raspberry Yogurt            3346083
# 37                         Fat Free Strawberry Yogurt            3346083
# 38                                  Blackberry Yogurt            3346083
# 39  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 40  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 41   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 42  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 43  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 44  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 45                          Total 0% Raspberry Yogurt            3346083
# 46                         Fat Free Strawberry Yogurt            3346083
# 47                                  Blackberry Yogurt            3346083
# 48  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 49  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
#
#     item_set_count  antecedent_count  consequent_count  \
# 0              101               123               128
# 1              101               128               123
# 2              101               123               128
# 3              101               123               128
# 4              101               128               123
# 5              101               123               128
# 6              101               128               123
# 7              101               147               117
# 8              101               147               117
# 9              101               117               147
# 10             101               117               147
# 11             101               147               117
# 12             101               147               117
# 13             101               117               147
# 14             101               117               147
# 15             101               119               145
# 16             101               145               119
# 17             101               119               145
# 18             101               145               119
# 19             101               145               119
# 20             101               119               145
# 21             101               145               119
# 22             101               132               133
# 23             101               132               133
# 24             101               133               132
# 25             101               132               133
# 26             101               133               132
# 27             101               133               132
# 28             101               132               133
# 29             101               133               132
# 30             103               129               139
# 31             103               139               129
# 32             103               139               129
# 33             103               139               129
# 34             103               129               139
# 35             103               139               129
# 36             103               139               129
# 37             103               129               139
# 38             103               129               139
# 39             103               144               125
# 40             103               144               125
# 41             103               125               144
# 42             103               144               125
# 43             103               125               144
# 44             103               144               125
# 45             103               144               125
# 46             103               125               144
# 47             103               125               144
# 48             102               123               145
# 49             102               145               123
#
#                                      antecedent_items   support  confidence  \
# 0   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 1   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 2   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 3   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 4   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 5   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 6   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 7   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 8   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 9   [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 10  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 11  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 12  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 13  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 14  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 15  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 16  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 17  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 18  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 19  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 20  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 21  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 22  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 23  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 24  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 25  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 26  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 27  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 28  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 29  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 30  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 31  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 32  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 33  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 34  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 35  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 36  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 37  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 38  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 39  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 40  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 41  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 42  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 43  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 44  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 45  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 46  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 47  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 48  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.829268
# 49  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.703448
#
#        lift
# 0   21466.0
# 1   21466.0
# 2   21466.0
# 3   21466.0
# 4   21466.0
# 5   21466.0
# 6   21466.0
# 7   19650.0
# 8   19650.0
# 9   19650.0
# 10  19650.0
# 11  19650.0
# 12  19650.0
# 13  19650.0
# 14  19650.0
# 15  19586.0
# 16  19586.0
# 17  19586.0
# 18  19586.0
# 19  19586.0
# 20  19586.0
# 21  19586.0
# 22  19250.0
# 23  19250.0
# 24  19250.0
# 25  19250.0
# 26  19250.0
# 27  19250.0
# 28  19250.0
# 29  19250.0
# 30  19221.0
# 31  19221.0
# 32  19221.0
# 33  19221.0
# 34  19221.0
# 35  19221.0
# 36  19221.0
# 37  19221.0
# 38  19221.0
# 39  19147.0
# 40  19147.0
# 41  19147.0
# 42  19147.0
# 43  19147.0
# 44  19147.0
# 45  19147.0
# 46  19147.0
# 47  19147.0
# 48  19137.0
# 49  19137.0

# %% [markdown]
# The yogurts have got some insane lift (*over 9,000*). Why do you think that might be?

# %% [markdown]
# **Answer:** Yogurts probably have such high lift because people are incredibly likely to buy more than one yogurt (and more than one type of yogurt) at a time.

# %%
# Query the rule set if you have to to find out more.
# Out:
# data/rules.tsv.xz

# %% [markdown]
# ## Network Visualization for Consequents with Single Antecedents
#
# Let’s now visualize a small subset of 1,000,000+ rules. First, filter the rule set for the following to whittle it down to something more manageable:
#
# 1. The rule must have exactly `1` antecedent item. (There should be 38,684 such rules.)
# 2. The lift must be between `5` and `20`. (There should be 1,596 such rules, including the prior criterion.)
# 3. Either the antecedent or consequent of the rule must contain `'Hummus'`, but not both. (This should get you down to 26 rules.)
#     * Convert the antecedents `list`-typed column to a `str`-typed column (`antecedent_item`) since there will only be a single antecedent in the subset.
#     * Replace any item containing `'Hummus'` to just `'Hummus'`. This will make the visualization more readable later.
#
# Hint: your code may run more efficiently if you re-order certain processing steps.
#
# Assign the subset to `df_rules_subset`.

# %%
# Define df_rules_subset.

# 1:
df_rules_subset = df_rules
condition1 = df_rules_subset['antecedent_items'].str.len() == 1
df_rules_subset = df_rules_subset[condition1]

# 2:
condition2 = df_rules_subset['lift'] <= 20
df_rules_subset = df_rules_subset[condition2]
condition3 = df_rules_subset['lift'] >= 5
df_rules_subset = df_rules_subset[condition3]

# 3:
condition4 = df_rules_subset['consequent_item'].str.contains('Hummus') != 0
df_rules_subset = df_rules_subset[condition4]

df_rules_subset['antecedent_items'] = df_rules_subset['antecedent_items'].astype(str)
condition5 = df_rules_subset['antecedent_items'].str.contains('Hummus') == 0
df_rules_subset = df_rules_subset[condition5]

df_rules_subset.rename(
    columns={"antecedent_items": "antecedent_item"}, inplace=True)

len(df_rules_subset)
# Out:
# 26

# %% [markdown]
# Build a network `graph_rules_subset` from the association rules subset.

# %%
# Define graph_rules_subset, add the graph’s edges, and plot it. You may need a large figure size, smaller node size, and smaller font size.

from_nodes = [list(x)[0] for x in df_rules_subset['antecedent_item']]
from_nodes
from_nodes = df_rules_subset['antecedent_item']
to_nodes = df_rules_subset['consequent_item']

connections = []

for from_node, to_node in zip(from_nodes, to_nodes):
    connections.append([from_node, to_node])

graph_rules_subset = nx.MultiDiGraph()

graph_rules_subset.add_edges_from(
    connections
)

# Then render the graph.
plt.figure(1, figsize=(8, 8))
nx.draw_networkx(graph_rules_subset,
                 arrows=True,
                 node_size=250,
                 font_size=6,
                 node_color="tab:pink",
                 font_color='blue',
                 edge_color='gray',
                 connectionstyle='arc3, rad=0.1')

# %% [markdown]
# What can you tell about people who buy hummus?

# %% [markdown]
# **Answer:** People who buy hummus buy a wide variety of other items, always buying items that they plan to eat with the hummus.

# %% [markdown]
# ## Make a Prediction
#
# Given that the basket of items contains the following items, use the full set of association rules to predict the next 20 most likely items (consequents) that the person will add to the basket in descending order of lift:
#
# * `'Orange Bell Pepper'`
# * `'Organic Red Bell Pepper'`
#
# Hint: a single item in the basket may be a better predictor of some consequents than both items considered together. You must consider both or either, but not neither.

# %%
basket = {'Orange Bell Pepper', 'Organic Red Bell Pepper'}

df_rules_bp = df_rules.copy()

# condition_cbp = df_rules['consequent_item'].str.contains(
#     'Orange Bell Pepper') | df_rules['consequent_item'].str.contains('Organic Red Bell Pepper')
df_rules_bp['antecedent_items'] = df_rules_bp['antecedent_items'].astype(str)
condition_bp = df_rules_bp['antecedent_items'].str.contains('Orange Bell Pepper') | df_rules_bp['antecedent_items'].str.contains('Organic Red Bell Pepper')

df_rules_bp[condition_bp] \
        .sort_values('lift', ascending=False) \
        .head(20)
# Out:
#                                       consequent_item  transaction_count  \
# 342462  Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 345882  Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 346832       Nonfat Icelandic Style Strawberry Yogurt            3346083
# 346901                       Non Fat Raspberry Yogurt            3346083
# 347498                           Organic Strawberries            3346083
# 347499                            Organic Bell Pepper            3346083
# 349820                         Bag of Organic Bananas            3346083
# 349879                            Organic Bell Pepper            3346083
# 349880                         Bag of Organic Bananas            3346083
# 349819                            Organic Bell Pepper            3346083
# 349532  Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 350991                       Non Fat Raspberry Yogurt            3346083
# 350852  Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 351360  Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 351433       Nonfat Icelandic Style Strawberry Yogurt            3346083
# 351881  Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 352236                        Organic Red Bell Pepper            3346083
# 352237                            Organic Raspberries            3346083
# 352283                     Vanilla Skyr Nonfat Yogurt            3346083
# 352884                    Organic Frozen Mango Chunks            3346083
#
#         item_set_count  antecedent_count  consequent_count  \
# 342462             100               209             19962
# 345882             132               311             19962
# 346832             100               441             11025
# 346901             184               529             16953
# 347498             189              1885              5000
# 347499             189              1885              5000
# 349820             197              1885              5661
# 349879             249              2389              5661
# 349880             249              2389              5661
# 349819             197              1885              5661
# 349532             184               494             19962
# 350991             132               441             16953
# 350852             167               471             19962
# 351360             101               291             19962
# 351433             101               529             11025
# 351881             133               392             19962
# 352236             102               946              6443
# 352237             102               946              6443
# 352283             167               529             18899
# 352884             109               612             10938
#
#                                          antecedent_items   support  \
# 342462  ['Nonfat Icelandic Style Strawberry Yogurt', '...  0.000030
# 345882  ['Non Fat Raspberry Yogurt', 'Orange Bell Pepp...  0.000039
# 346832  ['Icelandic Style Skyr Blueberry Non-fat Yogur...  0.000030
# 346901  ['Icelandic Style Skyr Blueberry Non-fat Yogur...  0.000055
# 347498  ['Organic Orange Bell Pepper', 'Organic Raspbe...  0.000056
# 347499  ['Organic Orange Bell Pepper', 'Organic Raspbe...  0.000056
# 349820  ['Organic Orange Bell Pepper', 'Organic Raspbe...  0.000059
# 349879  ['Organic Hass Avocado', 'Organic Orange Bell ...  0.000074
# 349880  ['Organic Hass Avocado', 'Organic Orange Bell ...  0.000074
# 349819  ['Organic Orange Bell Pepper', 'Organic Raspbe...  0.000059
# 349532  ['Non Fat Raspberry Yogurt', 'Organic Red Bell...  0.000055
# 350991  ['Icelandic Style Skyr Blueberry Non-fat Yogur...  0.000039
# 350852  ['Organic Red Bell Pepper', 'Vanilla Skyr Nonf...  0.000050
# 351360  ['Nonfat Icelandic Style Strawberry Yogurt', '...  0.000030
# 351433  ['Icelandic Style Skyr Blueberry Non-fat Yogur...  0.000030
# 351881  ['Orange Bell Pepper', 'Vanilla Skyr Nonfat Yo...  0.000040
# 352236  ['Organic Blueberries', 'Organic Orange Bell P...  0.000030
# 352237  ['Organic Blueberries', 'Organic Orange Bell P...  0.000030
# 352283  ['Icelandic Style Skyr Blueberry Non-fat Yogur...  0.000050
# 352884  ['Organic Red Bell Pepper', 'Organic Sliced Pe...  0.000033
#
#         confidence  lift
# 342462    0.478469  80.0
# 345882    0.424437  71.0
# 346832    0.226757  69.0
# 346901    0.347826  69.0
# 347498    0.100265  67.0
# 347499    0.100265  67.0
# 349820    0.104509  62.0
# 349879    0.104228  62.0
# 349880    0.104228  62.0
# 349819    0.104509  62.0
# 349532    0.372470  62.0
# 350991    0.299320  59.0
# 350852    0.354565  59.0
# 351360    0.347079  58.0
# 351433    0.190926  58.0
# 351881    0.339286  57.0
# 352236    0.107822  56.0
# 352237    0.107822  56.0
# 352283    0.315690  56.0
# 352884    0.178105  54.0

# %% [markdown]
# ## Bonus: Other Interesting Findings
#
# Find and share something else interesting about these association rules. It can be a graph, table, or some other format that illustrates your point.

# %%
df_rules_subset2 = df_rules
condition = df_rules_subset2['antecedent_items'].str.len() == 1
df_rules_subset2 = df_rules_subset2[condition]

df_rules_subset2[condition_bp]
# Out:
# /var/folders/17/kd7ctmb50z57l4pr3wdxdth00000gn/T/ipykernel_1696/2972626687.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_rules_subset2[condition_bp]
#                   consequent_item  transaction_count  item_set_count  \
# 364344        Organic Bell Pepper            3346083            2449
# 370169         Yellow Bell Pepper            3346083            7520
# 386994        Organic Bell Pepper            3346083            6024
# 396572    Organic Red Bell Pepper            3346083            2259
# 449846                Red Peppers            3346083            5529
# 480595          Green Bell Pepper            3346083            7086
# 514125          Green Bell Pepper            3346083            1169
# 531201          Green Bell Pepper            3346083            4144
# 572390           Organic Cucumber            3346083            1458
# 657541           Organic Cucumber            3346083            6480
# 661896     Organic Grape Tomatoes            3346083            1222
# 667831           Organic Zucchini            3346083            1498
# 683930        Organic Raspberries            3346083            1885
# 687012   Apple Honeycrisp Organic            3346083            1146
# 703709       Organic Yellow Onion            3346083            1493
# 715555       Organic Yellow Onion            3346083            7919
# 739012             Cucumber Kirby            3346083            4374
# 757673           Organic Zucchini            3346083            6727
# 778370       Organic Hass Avocado            3346083            2389
# 813558             Organic Garlic            3346083            6222
# 829779       Organic Hass Avocado            3346083           11641
# 856471       Organic Strawberries            3346083            2509
# 866996                Large Lemon            3346083            5322
# 874879                      Limes            3346083            4761
# 884317                      Limes            3346083            6784
# 893069       Organic Strawberries            3346083           12471
# 893725        Organic Raspberries            3346083            6443
# 908134     Bag of Organic Bananas            3346083            3159
# 913472            Organic Avocado            3346083            5421
# 926790       Organic Baby Spinach            3346083            1911
# 929544       Organic Baby Spinach            3346083           10306
# 959033            Organic Avocado            3346083            6753
# 972480     Bag of Organic Bananas            3346083           13606
# 982120       Organic Baby Spinach            3346083            5658
# 988782                     Banana            3346083           10624
# 1004835      Organic Hass Avocado            3346083            4262
# 1012408      Organic Strawberries            3346083            4973
# 1025462                    Banana            3346083           10895
# 1031837    Bag of Organic Bananas            3346083            5145
#
#          antecedent_count  consequent_count              antecedent_items  \
# 364344              11005             24331  [Organic Orange Bell Pepper]
# 370169              41052             26625          [Orange Bell Pepper]
# 386994              59878             24331     [Organic Red Bell Pepper]
# 396572              11005             59878  [Organic Orange Bell Pepper]
# 449846              41052             58185          [Orange Bell Pepper]
# 480595              59878             58005     [Organic Red Bell Pepper]
# 514125              11005             58005  [Organic Orange Bell Pepper]
# 531201              41052             58005          [Orange Bell Pepper]
# 572390              11005             85005  [Organic Orange Bell Pepper]
# 657541              59878             85005     [Organic Red Bell Pepper]
# 661896              11005             88078  [Organic Orange Bell Pepper]
# 667831              11005            109412  [Organic Orange Bell Pepper]
# 683930              11005            142603  [Organic Orange Bell Pepper]
# 687012              11005             87272  [Organic Orange Bell Pepper]
# 703709              11005            117716  [Organic Orange Bell Pepper]
# 715555              59878            117716     [Organic Red Bell Pepper]
# 739012              41052             99728          [Orange Bell Pepper]
# 757673              59878            109412     [Organic Red Bell Pepper]
# 778370              11005            220877  [Organic Orange Bell Pepper]
# 813558              59878            113936     [Organic Red Bell Pepper]
# 829779              59878            220877     [Organic Red Bell Pepper]
# 856471              11005            275577  [Organic Orange Bell Pepper]
# 866996              41052            160792          [Orange Bell Pepper]
# 874879              41052            146660          [Orange Bell Pepper]
# 884317              59878            146660     [Organic Red Bell Pepper]
# 893069              59878            275577     [Organic Red Bell Pepper]
# 893725              59878            142603     [Organic Red Bell Pepper]
# 908134              11005            394930  [Organic Orange Bell Pepper]
# 913472              41052            184224          [Orange Bell Pepper]
# 926790              11005            251705  [Organic Orange Bell Pepper]
# 929544              59878            251705     [Organic Red Bell Pepper]
# 959033              59878            184224     [Organic Red Bell Pepper]
# 972480              59878            394930     [Organic Red Bell Pepper]
# 982120              41052            251705          [Orange Bell Pepper]
# 988782              41052            491291          [Orange Bell Pepper]
# 1004835             41052            220877          [Orange Bell Pepper]
# 1012408             41052            275577          [Orange Bell Pepper]
# 1025462             59878            491291     [Organic Red Bell Pepper]
# 1031837             41052            394930          [Orange Bell Pepper]
#
#           support  confidence  lift
# 364344   0.000732    0.222535  31.0
# 370169   0.002247    0.183182  23.0
# 386994   0.001800    0.100605  14.0
# 396572   0.000675    0.205270  11.0
# 449846   0.001652    0.134683   8.0
# 480595   0.002118    0.118341   7.0
# 514125   0.000349    0.106224   6.0
# 531201   0.001238    0.100945   6.0
# 572390   0.000436    0.132485   5.0
# 657541   0.001937    0.108220   4.0
# 661896   0.000365    0.111040   4.0
# 667831   0.000448    0.136120   4.0
# 683930   0.000563    0.171286   4.0
# 687012   0.000342    0.104134   4.0
# 703709   0.000446    0.135666   4.0
# 715555   0.002367    0.132252   4.0
# 739012   0.001307    0.106548   4.0
# 757673   0.002010    0.112345   3.0
# 778370   0.000714    0.217083   3.0
# 813558   0.001859    0.103911   3.0
# 829779   0.003479    0.194412   3.0
# 856471   0.000750    0.227987   3.0
# 866996   0.001591    0.129640   3.0
# 874879   0.001423    0.115975   3.0
# 884317   0.002027    0.113297   3.0
# 893069   0.003727    0.208273   3.0
# 893725   0.001926    0.107602   3.0
# 908134   0.000944    0.287051   2.0
# 913472   0.001620    0.132052   2.0
# 926790   0.000571    0.173648   2.0
# 929544   0.003080    0.172117   2.0
# 959033   0.002018    0.112779   2.0
# 972480   0.004066    0.227229   2.0
# 982120   0.001691    0.137825   2.0
# 988782   0.003175    0.258794   2.0
# 1004835  0.001274    0.103820   2.0
# 1012408  0.001486    0.121139   1.0
# 1025462  0.003256    0.181953   1.0
# 1031837  0.001538    0.125329   1.0

# %% [markdown]
# **Findings:** Based on the lift values of the above table, I found that it is not very common for people to just buy 2 different Bell Peppers (meaning any amount and combinations of only 2 different types), and even less common for them to just buy Bell Pepper and a single other item.
